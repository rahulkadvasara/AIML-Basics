# %% [markdown]
# Assignment 5 exercise questions

# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series([10, 20, 30, 40, 50])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print("Index : ", data.index)
print("Values : ", data.values)
# Out:
# Index :  RangeIndex(start=0, stop=5, step=1)
# Values :  [10 20 30 40 50]

# %%
arr = np.array([10, 20, 30, 40, 50])
print("Array Type : ", type(arr))
print("Series Type : ", type(data))
print("Array Addition : ", arr + 5)
print("Series Addition : ", data + 5)
# Out:
# Array Type :  <class 'numpy.ndarray'>
# Series Type :  <class 'pandas.core.series.Series'>
# Array Addition :  [15 25 35 45 55]
# Series Addition :  0    15
# 1    25
# 2    35
# 3    45
# 4    55
# dtype: int64

# %%
custom = pd.Series([100, 200, 300],index=['a','b','c'])
print(custom)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
print("Value at index 0 : ", data[0])
# Out:
# Value at index 0 :  10

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3],[4, 5, 6])
plt.title("Line Plot")
plt.show()

# %%
plt.bar(['A','B','C'],[10, 20, 30])
plt.title("Bar Chart")
plt.show()

# %%
plt.scatter([1, 2, 3],[4, 5, 6])
plt.title("Scatter Plot")
plt.show()
